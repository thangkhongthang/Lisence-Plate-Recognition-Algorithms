# %%
import nbimporter
import math
import cv2
import numpy as np
import Preprocess

ADAPTIVE_THRESH_BLOCK_SIZE = 19
ADAPTIVE_THRESH_WEIGHT = 9

Min_char_area = 0.015
Max_char_area = 0.06

Min_char = 0.01
Max_char = 0.09

Min_ratio_char = 0.25
Max_ratio_char = 0.7

max_size_plate = 18000
min_size_plate = 5000

RESIZED_IMAGE_WIDTH = 20
RESIZED_IMAGE_HEIGHT = 30

tongframe = 0
biensotimthay = 0

# Load KNN model
npaClassifications = np.loadtxt("classifications.txt", np.float32)
npaFlattenedImages = np.loadtxt("flattened_images.txt", np.float32)
npaClassifications = npaClassifications.reshape(
    (npaClassifications.size, 1))  # reshape numpy array to 1d, necessary to pass to call to train
kNearest = cv2.ml.KNearest_create()  # instantiate KNN object
kNearest.train(npaFlattenedImages, cv2.ml.ROW_SAMPLE, npaClassifications)

# Read video
cap = cv2.VideoCapture('data/image/test1.mp4')

while (cap.isOpened()):
    ret, img = cap.read()
    if not ret:  # Kiểm tra nếu video hết frame
        print("End of video")
        break

    tongframe += 1
    
    # Giảm độ phân giải của ảnh để giảm tải cho hệ thống
    img = cv2.resize(img, (640, 360))

    # Image preprocessing
    imgGrayscaleplate, imgThreshplate = Preprocess.preprocess(img)
    canny_image = cv2.Canny(imgThreshplate, 250, 255)  # Canny Edge
    kernel = np.ones((3, 3), np.uint8)
    dilated_image = cv2.dilate(canny_image, kernel, iterations=1)  # Dilation

    # Filter out license plates
    contours, hierarchy = cv2.findContours(dilated_image, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]  # Pick out 10 biggest contours
    screenCnt = []
    for c in contours:
        peri = cv2.arcLength(c, True)  # Tính chu vi
        approx = cv2.approxPolyDP(c, 0.06 * peri, True)  # Approximate the edges of contours
        [x, y, w, h] = cv2.boundingRect(approx.copy())
        ratio = w / h
        if (len(approx) == 4) and (0.8 <= ratio <= 1.5 or 4.5 <= ratio <= 6.5):
            screenCnt.append(approx)
    if not screenCnt:
        detected = 0
        print("No plate detected")
    else:
        detected = 1

    if detected == 1:
        n = 1
        for screenCnt in screenCnt:

            ################## Find the angle of the license plate ###############
            (x1, y1) = screenCnt[0, 0]
            (x2, y2) = screenCnt[1, 0]
            (x3, y3) = screenCnt[2, 0]
            (x4, y4) = screenCnt[3, 0]
            array = [[x1, y1], [x2, y2], [x3, y3], [x4, y4]]
            sorted_array = sorted(array, reverse=True, key=lambda x: x[1])
            (x1, y1) = sorted_array[0]
            (x2, y2) = sorted_array[1]

            doi = abs(y1 - y2)
            ke = abs(x1 - x2)
            angle = math.atan(doi / ke) * (180.0 / math.pi)
            #################################################

            # Masking the part other than the number plate
            mask = np.zeros(imgGrayscaleplate.shape, np.uint8)
            new_image = cv2.drawContours(mask, [screenCnt], 0, 255, -1)

            # Now crop
            (x, y) = np.where(mask == 255)
            (topx, topy) = (np.min(x), np.min(y))
            (bottomx, bottomy) = (np.max(x), np.max(y))

            roi = img[topx:bottomx + 1, topy:bottomy + 1]
            imgThresh = imgThreshplate[topx:bottomx + 1, topy:bottomy + 1]

            ptPlateCenter = (bottomx - topx) / 2, (bottomy - topy) / 2

            if x1 < x2:
                rotationMatrix = cv2.getRotationMatrix2D(ptPlateCenter, -angle, 1.0)
            else:
                rotationMatrix = cv2.getRotationMatrix2D(ptPlateCenter, angle, 1.0)

            roi = cv2.warpAffine(roi, rotationMatrix, (bottomy - topy, bottomx - topx))
            imgThresh = cv2.warpAffine(imgThresh, rotationMatrix, (bottomy - topy, bottomx - topy))

            roi = cv2.resize(roi, (0, 0), fx=3, fy=3)
            imgThresh = cv2.resize(imgThresh, (0, 0), fx=3, fy=3)

            # License Plate preprocessing
            kerel3 = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
            thre_mor = cv2.morphologyEx(imgThresh, cv2.MORPH_DILATE, kerel3)
            cont, hier = cv2.findContours(thre_mor, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            # Character segmentation
            char_x_ind = {}
            char_x = []
            height, width, _ = roi.shape
            roiarea = height * width

            for ind, cnt in enumerate(cont):
                area = cv2.contourArea(cnt)
                (x, y, w, h) = cv2.boundingRect(cont[ind])
                ratiochar = w / h
                if (Min_char * roiarea < area < Max_char * roiarea) and (0.25 < ratiochar < 0.7):
                    if x in char_x:  # Sử dụng để dù cho trùng x vẫn vẽ được
                        x = x + 1
                    char_x.append(x)
                    char_x_ind[x] = ind

            # Character recognition
            if len(char_x) in range(7, 10):
                cv2.drawContours(img, [screenCnt], -1, (0, 255, 0), 3)

                char_x = sorted(char_x)
                strFinalString = ""
                first_line = ""
                second_line = ""

                for i in char_x:
                    (x, y, w, h) = cv2.boundingRect(cont[char_x_ind[i]])
                    cv2.rectangle(roi, (x, y), (x + w, y + h), (0, 255, 0), 2)

                    imgROI = thre_mor[y:y + h, x:x + w]  # crop characters

                    imgROIResized = cv2.resize(imgROI,
                                               (RESIZED_IMAGE_WIDTH, RESIZED_IMAGE_HEIGHT))  # resize
                    npaROIResized = imgROIResized.reshape(
                        (1, RESIZED_IMAGE_WIDTH * RESIZED_IMAGE_HEIGHT))  # đưa hình ảnh về mảng 1 chiều
                    npaROIResized = np.float32(npaROIResized)  # chuyển mảng về dạng float
                    _, npaResults, neigh_resp, dists = kNearest.findNearest(npaROIResized, k=3)
                    strCurrentChar = str(chr(int(npaResults[0][0])))  # ASCII of the character
                    cv2.putText(roi, strCurrentChar, (x, y + 50), cv2.FONT_HERSHEY_DUPLEX, 2, (0, 255, 255), 3)

                    if (y < height / 3):  # decide 1 or 2-line license plate
                        first_line = first_line + strCurrentChar
                    else:
                        second_line = second_line + strCurrentChar

                strFinalString = first_line + second_line
                print("\n License Plate " + str(n) + " is: " + first_line + " - " + second_line + "\n")
                cv2.putText(img, strFinalString, (topy, topx), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 255, 255), 1)
                n += 1
                biensotimthay += 1

                # Hiển thị kết quả trên màn hình
                cv2.imshow("License Plate Detection", img)

    print("number of plates found", biensotimthay)
    print("total frame", tongframe)
    print("plate found rate:", 100 * biensotimthay / tongframe, "%")

    # Tăng giá trị của cv2.waitKey() để video chạy chậm hơn
    if cv2.waitKey(50) & 0xFF == ord('q'):  # 50 mili giây giữa các frame
        break

# Giải phóng tài nguyên
cap.release()
cv2.destroyAllWindows()
# Out:
# No plate detected
# number of plates found 0
# total frame 1
# plate found rate: 0.0 %
# number of plates found 0
# total frame 2
# plate found rate: 0.0 %
# number of plates found 0
# total frame 3
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 4
# plate found rate: 0.0 %
# number of plates found 0
# total frame 5
# plate found rate: 0.0 %
# number of plates found 0
# total frame 6
# plate found rate: 0.0 %
# number of plates found 0
# total frame 7
# plate found rate: 0.0 %
# number of plates found 0
# total frame 8
# plate found rate: 0.0 %
# number of plates found 0
# total frame 9
# plate found rate: 0.0 %
# number of plates found 0
# total frame 10
# plate found rate: 0.0 %
# number of plates found 0
# total frame 11
# plate found rate: 0.0 %
# number of plates found 0
# total frame 12
# plate found rate: 0.0 %
# number of plates found 0
# total frame 13
# plate found rate: 0.0 %
# number of plates found 0
# total frame 14
# plate found rate: 0.0 %
# number of plates found 0
# total frame 15
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 16
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 17
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 18
# plate found rate: 0.0 %
# number of plates found 0
# total frame 19
# plate found rate: 0.0 %
# number of plates found 0
# total frame 20
# plate found rate: 0.0 %
# number of plates found 0
# total frame 21
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 22
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 23
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 24
# plate found rate: 0.0 %
# number of plates found 0
# total frame 25
# plate found rate: 0.0 %
# number of plates found 0
# total frame 26
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 27
# plate found rate: 0.0 %
# number of plates found 0
# total frame 28
# plate found rate: 0.0 %
# number of plates found 0
# total frame 29
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 30
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 31
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 32
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 33
# plate found rate: 0.0 %
# number of plates found 0
# total frame 34
# plate found rate: 0.0 %
# number of plates found 0
# total frame 35
# plate found rate: 0.0 %
# number of plates found 0
# total frame 36
# plate found rate: 0.0 %
# number of plates found 0
# total frame 37
# plate found rate: 0.0 %
# number of plates found 0
# total frame 38
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 39
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 40
# plate found rate: 0.0 %
# number of plates found 0
# total frame 41
# plate found rate: 0.0 %
# number of plates found 0
# total frame 42
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 43
# plate found rate: 0.0 %
# number of plates found 0
# total frame 44
# plate found rate: 0.0 %
# number of plates found 0
# total frame 45
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 46
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 47
# plate found rate: 0.0 %
# number of plates found 0
# total frame 48
# plate found rate: 0.0 %
# number of plates found 0
# total frame 49
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 50
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 51
# plate found rate: 0.0 %
# number of plates found 0
# total frame 52
# plate found rate: 0.0 %
# No plate detected
# number of plates found 0
# total frame 53
# plate found rate: 0.0 %
# number of plates found 0
# total frame 54
# plate found rate: 0.0 %
# number of plates found 0
# total frame 55
# plate found rate: 0.0 %
#
#  License Plate 1 is: Y0 - 33611
#
# number of plates found 1
# total frame 56
# plate found rate: 1.7857142857142858 %
# number of plates found 1
# total frame 57
# plate found rate: 1.7543859649122806 %
# number of plates found 1
# total frame 58
# plate found rate: 1.7241379310344827 %
#
#  License Plate 1 is: 2Z - 53621
#
#
#  License Plate 2 is: 2Z8 - 53621
#
# number of plates found 3
# total frame 59
# plate found rate: 5.084745762711864 %
# number of plates found 3
# total frame 60
# plate found rate: 5.0 %
#
#  License Plate 1 is: 2Z8Z - 53621
#
# number of plates found 4
# total frame 61
# plate found rate: 6.557377049180328 %
#
#  License Plate 1 is: 222 - 53621
#
# number of plates found 5
# total frame 62
# plate found rate: 8.064516129032258 %
#
#  License Plate 1 is: 2Z2 - 53621
#
# number of plates found 6
# total frame 63
# plate found rate: 9.523809523809524 %
# number of plates found 6
# total frame 64
# plate found rate: 9.375 %
# number of plates found 6
# total frame 65
# plate found rate: 9.23076923076923 %
#
#  License Plate 1 is: 228 - 53621
#
# number of plates found 7
# total frame 66
# plate found rate: 10.606060606060606 %
# number of plates found 7
# total frame 67
# plate found rate: 10.447761194029852 %
# number of plates found 7
# total frame 68
# plate found rate: 10.294117647058824 %
# number of plates found 7
# total frame 69
# plate found rate: 10.144927536231885 %
# number of plates found 7
# total frame 70
# plate found rate: 10.0 %
# No plate detected
# number of plates found 7
# total frame 71
# plate found rate: 9.859154929577464 %
# number of plates found 7
# total frame 72
# plate found rate: 9.722222222222221 %
# number of plates found 7
# total frame 73
# plate found rate: 9.58904109589041 %
# No plate detected
# number of plates found 7
# total frame 74
# plate found rate: 9.45945945945946 %
# number of plates found 7
# total frame 75
# plate found rate: 9.333333333333334 %
# No plate detected
# number of plates found 7
# total frame 76
# plate found rate: 9.210526315789474 %
# No plate detected
# number of plates found 7
# total frame 77
# plate found rate: 9.090909090909092 %
# number of plates found 7
# total frame 78
# plate found rate: 8.974358974358974 %
# number of plates found 7
# total frame 79
# plate found rate: 8.860759493670885 %
# No plate detected
# number of plates found 7
# total frame 80
# plate found rate: 8.75 %
# number of plates found 7
# total frame 81
# plate found rate: 8.641975308641975 %
# number of plates found 7
# total frame 82
# plate found rate: 8.536585365853659 %
# No plate detected
# number of plates found 7
# total frame 83
# plate found rate: 8.433734939759036 %
# number of plates found 7
# total frame 84
# plate found rate: 8.333333333333334 %
# number of plates found 7
# total frame 85
# plate found rate: 8.235294117647058 %
# number of plates found 7
# total frame 86
# plate found rate: 8.13953488372093 %
# number of plates found 7
# total frame 87
# plate found rate: 8.045977011494253 %
# number of plates found 7
# total frame 88
# plate found rate: 7.954545454545454 %
# number of plates found 7
# total frame 89
# plate found rate: 7.865168539325842 %
# number of plates found 7
# total frame 90
# plate found rate: 7.777777777777778 %
# number of plates found 7
# total frame 91
# plate found rate: 7.6923076923076925 %
# number of plates found 7
# total frame 92
# plate found rate: 7.608695652173913 %
# number of plates found 7
# total frame 93
# plate found rate: 7.526881720430108 %
# number of plates found 7
# total frame 94
# plate found rate: 7.446808510638298 %
# number of plates found 7
# total frame 95
# plate found rate: 7.368421052631579 %
# number of plates found 7
# total frame 96
# plate found rate: 7.291666666666667 %
# number of plates found 7
# total frame 97
# plate found rate: 7.216494845360825 %
#
#  License Plate 1 is: C1 - Z4559
#
# number of plates found 8
# total frame 98
# plate found rate: 8.16326530612245 %
# number of plates found 8
# total frame 99
# plate found rate: 8.080808080808081 %
#
#  License Plate 1 is: 994 - 2455
#
# number of plates found 9
# total frame 100
# plate found rate: 9.0 %
#
#  License Plate 1 is: 41 - 2456Q
#
#
#  License Plate 2 is: 99C - 2455
#
# number of plates found 11
# total frame 101
# plate found rate: 10.891089108910892 %
# No plate detected
# number of plates found 11
# total frame 102
# plate found rate: 10.784313725490197 %
# number of plates found 11
# total frame 103
# plate found rate: 10.679611650485437 %
# number of plates found 11
# total frame 104
# plate found rate: 10.576923076923077 %
# number of plates found 11
# total frame 105
# plate found rate: 10.476190476190476 %
# No plate detected
# number of plates found 11
# total frame 106
# plate found rate: 10.377358490566039 %
# number of plates found 11
# total frame 107
# plate found rate: 10.280373831775702 %
# number of plates found 11
# total frame 108
# plate found rate: 10.185185185185185 %
# number of plates found 11
# total frame 109
# plate found rate: 10.091743119266056 %
# number of plates found 11
# total frame 110
# plate found rate: 10.0 %
# number of plates found 11
# total frame 111
# plate found rate: 9.90990990990991 %
# number of plates found 11
# total frame 112
# plate found rate: 9.821428571428571 %
# number of plates found 11
# total frame 113
# plate found rate: 9.734513274336283 %
#
#  License Plate 1 is: 228L - 41A11
#
# number of plates found 12
# total frame 114
# plate found rate: 10.526315789473685 %
# No plate detected
# number of plates found 12
# total frame 115
# plate found rate: 10.434782608695652 %
# No plate detected
# number of plates found 12
# total frame 116
# plate found rate: 10.344827586206897 %
# number of plates found 12
# total frame 117
# plate found rate: 10.256410256410257 %
# number of plates found 12
# total frame 118
# plate found rate: 10.169491525423728 %
# No plate detected
# number of plates found 12
# total frame 119
# plate found rate: 10.084033613445378 %
# number of plates found 12
# total frame 120
# plate found rate: 10.0 %
# number of plates found 12
# total frame 121
# plate found rate: 9.917355371900827 %
# No plate detected
# number of plates found 12
# total frame 122
# plate found rate: 9.836065573770492 %
#
#  License Plate 1 is: 282 - 21621
#
# number of plates found 13
# total frame 123
# plate found rate: 10.56910569105691 %
# number of plates found 13
# total frame 124
# plate found rate: 10.483870967741936 %
# number of plates found 13
# total frame 125
# plate found rate: 10.4 %
# number of plates found 13
# total frame 126
# plate found rate: 10.317460317460318 %
# number of plates found 13
# total frame 127
# plate found rate: 10.236220472440944 %
# number of plates found 13
# total frame 128
# plate found rate: 10.15625 %
# number of plates found 13
# total frame 129
# plate found rate: 10.077519379844961 %
# number of plates found 13
# total frame 130
# plate found rate: 10.0 %
#
#  License Plate 1 is: 93CT - 15455
#
# number of plates found 14
# total frame 131
# plate found rate: 10.687022900763358 %
# number of plates found 14
# total frame 132
# plate found rate: 10.606060606060606 %
# number of plates found 14
# total frame 133
# plate found rate: 10.526315789473685 %
#
#  License Plate 1 is: C1 - 15985
#
# number of plates found 15
# total frame 134
# plate found rate: 11.194029850746269 %
# number of plates found 15
# total frame 135
# plate found rate: 11.11111111111111 %
# number of plates found 15
# total frame 136
# plate found rate: 11.029411764705882 %
# number of plates found 15
# total frame 137
# plate found rate: 10.94890510948905 %
# number of plates found 15
# total frame 138
# plate found rate: 10.869565217391305 %
# number of plates found 15
# total frame 139
# plate found rate: 10.79136690647482 %
#
#  License Plate 1 is:  - 1514615
#
# number of plates found 16
# total frame 140
# plate found rate: 11.428571428571429 %
#
#  License Plate 1 is: CT - 35985
#
# number of plates found 17
# total frame 141
# plate found rate: 12.056737588652481 %
# number of plates found 17
# total frame 142
# plate found rate: 11.971830985915492 %
# number of plates found 17
# total frame 143
# plate found rate: 11.888111888111888 %
# number of plates found 17
# total frame 144
# plate found rate: 11.805555555555555 %
# number of plates found 17
# total frame 145
# plate found rate: 11.724137931034482 %
# number of plates found 17
# total frame 146
# plate found rate: 11.643835616438356 %
# number of plates found 17
# total frame 147
# plate found rate: 11.564625850340136 %
#
#  License Plate 1 is: ZZ8Z - 516Z
#
#
#  License Plate 2 is: C1 - 16965
#
# number of plates found 19
# total frame 148
# plate found rate: 12.837837837837839 %
# number of plates found 19
# total frame 149
# plate found rate: 12.751677852348994 %
# number of plates found 19
# total frame 150
# plate found rate: 12.666666666666666 %
# number of plates found 19
# total frame 151
# plate found rate: 12.582781456953642 %
# number of plates found 19
# total frame 152
# plate found rate: 12.5 %
#
#  License Plate 1 is: 41 - 15965
#
# number of plates found 20
# total frame 153
# plate found rate: 13.071895424836601 %
# number of plates found 20
# total frame 154
# plate found rate: 12.987012987012987 %
# number of plates found 20
# total frame 155
# plate found rate: 12.903225806451612 %
#
#  License Plate 1 is: C1 - 35965
#
# number of plates found 21
# total frame 156
# plate found rate: 13.461538461538462 %
# number of plates found 21
# total frame 157
# plate found rate: 13.375796178343949 %
#
#  License Plate 1 is: C1 - 35966
#
# number of plates found 22
# total frame 158
# plate found rate: 13.924050632911392 %
# number of plates found 22
# total frame 159
# plate found rate: 13.836477987421384 %
# number of plates found 22
# total frame 160
# plate found rate: 13.75 %
# number of plates found 22
# total frame 161
# plate found rate: 13.664596273291925 %
# number of plates found 22
# total frame 162
# plate found rate: 13.580246913580247 %
# number of plates found 22
# total frame 163
# plate found rate: 13.496932515337424 %
# number of plates found 22
# total frame 164
# plate found rate: 13.414634146341463 %
# number of plates found 22
# total frame 165
# plate found rate: 13.333333333333334 %
# number of plates found 22
# total frame 166
# plate found rate: 13.25301204819277 %
# number of plates found 22
# total frame 167
# plate found rate: 13.173652694610778 %
# number of plates found 22
# total frame 168
# plate found rate: 13.095238095238095 %
# number of plates found 22
# total frame 169
# plate found rate: 13.017751479289942 %
# number of plates found 22
# total frame 170
# plate found rate: 12.941176470588236 %
#
#  License Plate 1 is: C1 - 36965
#
# number of plates found 23
# total frame 171
# plate found rate: 13.450292397660819 %
#
#  License Plate 1 is: C1 - 36965
#
# number of plates found 24
# total frame 172
# plate found rate: 13.953488372093023 %
# End of video
